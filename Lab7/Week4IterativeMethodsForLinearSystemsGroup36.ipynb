# %% [markdown]
# <a href="https://colab.research.google.com/github/lmeloh/MetNumUN2023I/blob/main/Lab7/Week4IterativeMethodsForLinearSystemsGroup36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple iteration for systems of linear equations

# %% [markdown]
# First, generate a random diagonally dominant matrix, for testing.

# %%
import numpy as np
rndm = np.random.RandomState(1234)

n = 10
A = rndm.uniform(size=(n, n)) + np.diagflat([15]*n)
b = rndm.uniform(size=n)

# %%
A
# Out:
# array([[1.51915195e+01, 6.22108771e-01, 4.37727739e-01, 7.85358584e-01,
#         7.79975808e-01, 2.72592605e-01, 2.76464255e-01, 8.01872178e-01,
#         9.58139354e-01, 8.75932635e-01],
#        [3.57817270e-01, 1.55009951e+01, 6.83462935e-01, 7.12702027e-01,
#         3.70250755e-01, 5.61196186e-01, 5.03083165e-01, 1.37684496e-02,
#         7.72826622e-01, 8.82641191e-01],
#        [3.64885984e-01, 6.15396178e-01, 1.50753812e+01, 3.68824006e-01,
#         9.33140102e-01, 6.51378143e-01, 3.97202578e-01, 7.88730143e-01,
#         3.16836122e-01, 5.68098653e-01],
#        [8.69127390e-01, 4.36173424e-01, 8.02147642e-01, 1.51437668e+01,
#         7.04260971e-01, 7.04581308e-01, 2.18792106e-01, 9.24867629e-01,
#         4.42140755e-01, 9.09315959e-01],
#        [5.98092228e-02, 1.84287084e-01, 4.73552788e-02, 6.74880944e-01,
#         1.55946248e+01, 5.33310163e-01, 4.33240627e-02, 5.61433080e-01,
#         3.29668446e-01, 5.02966833e-01],
#        [1.11894318e-01, 6.07193706e-01, 5.65944643e-01, 6.76406199e-03,
#         6.17441709e-01, 1.59121229e+01, 7.90524133e-01, 9.92081466e-01,
#         9.58801762e-01, 7.91964135e-01],
#        [2.85250960e-01, 6.24916705e-01, 4.78093796e-01, 1.95675179e-01,
#         3.82317452e-01, 5.38736851e-02, 1.54516484e+01, 9.82004742e-01,
#         1.23942700e-01, 1.19380898e-01],
#        [7.38523056e-01, 5.87303633e-01, 4.71632534e-01, 1.07126817e-01,
#         2.29218565e-01, 8.99965195e-01, 4.16753538e-01, 1.55358517e+01,
#         6.20851659e-03, 3.00641706e-01],
#        [4.36893172e-01, 6.12148997e-01, 9.18198075e-01, 6.25736670e-01,
#         7.05997565e-01, 1.49833716e-01, 7.46063409e-01, 8.31006992e-01,
#         1.56337258e+01, 4.38309881e-01],
#        [1.52572775e-01, 5.68409615e-01, 5.28224278e-01, 9.51428764e-01,
#         4.80359179e-01, 5.02559563e-01, 5.36878193e-01, 8.19202067e-01,
#         5.71156381e-02, 1.56694217e+01]])

# %% [markdown]
# # I.  Jacobi iteration
#
# Given
#
# $$
# A x = b
# $$
#
# separate the diagonal part $D$,
#
# $$ A = D + (A - D) $$
#
# and write
#
# $$
# x = D^{-1} (D - A) x + D^{-1} b\;.
# $$
#
# Then iterate
#
# $$
# x_{n + 1} = B x_{n} + c\;,
# $$
#
# where
#
# $$
# B = D^{-1} (A - D) \qquad \text{and} \qquad c = D^{-1} b
# $$

# %% [markdown]
# Let's construct the matrix and the r.h.s. for the Jacobi iteration

# %%
diag_1d = np.diag(A)

B = -A.copy()
np.fill_diagonal(B, 0)

D = np.diag(diag_1d)
invD = np.diag(1./diag_1d)
BB = invD @ B 
c = invD @ b

# %%
# sanity checks
from numpy.testing import assert_allclose

assert_allclose(-B + D, A)


# xx is a "ground truth" solution, compute it using a direct method
xx = np.linalg.solve(A, b)

np.testing.assert_allclose(A@xx, b)
np.testing.assert_allclose(D@xx, B@xx + b)
np.testing.assert_allclose(xx, BB@xx + c)

# %% [markdown]
# Check that $\| B\| \leqslant 1$:

# %%
np.linalg.norm(BB)
# Out:
# 0.36436161983015336

# %% [markdown]
# ### Do the Jacobi iteration

# %%
n_iter = 50

x0 = np.ones(n)
x = x0
for _ in range(n_iter):
    x = BB @ x + c

# %%
# Check the result:

A @ x - b
# Out:
# array([ 1.11022302e-16,  0.00000000e+00, -2.22044605e-16, -1.11022302e-16,
#         1.11022302e-16,  0.00000000e+00, -2.42861287e-17,  0.00000000e+00,
#        -2.77555756e-17,  1.11022302e-16])

# %% [markdown]
# ### Task I.1
#
# Collect the proof-of-concept above into a single function implementing the Jacobi iteration. This function should receive the r.h.s. matrix $A$, the l.h.s. vector `b`, and the number of iterations to perform.
#
#
# The matrix $A$ in the illustration above is strongly diagonally dominant, by construction.
# What happens if the diagonal matrix elements of $A$ are made smaller? Check the convergence of the Jacobi iteration, and check the value of the norm of $B$.
#
# (20% of the total grade)

# %%
# ... ENTER YOUR CODE HERE ...
def jacobi(A, b, num_iter=1000):
    n = A.shape[0]
    diag_A = np.diag(A)
    B = np.zeros_like(A)
    
    for i in range(n):
        for j in range(n):
            if i != j:
                B[i, j] = -A[i, j] / diag_A[i]
    
    c = b / diag_A
    norm = np.linalg.norm(B)
    
    x0 = np.ones(n)
    x = x0
    for _ in range(num_iter):
        x = B @ x + c
    
    return x, norm


jacobi(A, b)
# Out:
# (array([ 0.03919429,  0.03780037,  0.04283232,  0.02365951,  0.05745031,
#         -0.00030244, -0.00577279,  0.03177549, -0.00422849,  0.05284648]),
#  0.36436161983015336)

# %% [markdown]
# # II. Seidel's iteration.

# %% [markdown]
# ##### Task II.1
#
# Implement the Seidel's iteration.
#
# Test it on a random matrix. Study the convergence of iterations, relate to the norm of the iteration matrix.
#
# (30% of the total grade)

# %%
import matplotlib.pyplot as plt

def gauss_seidel(A, b, X_i, eps, max_iter):

  x = X_i.copy()

  for i in range(max_iter):

    for j in range(A.shape[0]):
      x[j] = (b[j] - np.dot(A[j, :j], x[:j])) / A[j, j]

    norm_x = np.linalg.norm(x - X_i)
    if norm_x < eps:
      break

  return x

A = np.random.rand(10, 10)
b = np.random.rand(10)
print(A)
x = gauss_seidel(A, b, np.zeros(10), 1e-6, 100)

true_x = np.linalg.solve(A, b)

error = np.linalg.norm(x - true_x)
print(error)

error_list = []
for i in range(1, 100):
  x = gauss_seidel(A, b, np.zeros(10), 1e-6, i)
  error_list.append(np.linalg.norm(x - true_x))
# Out:
# [[0.62769607 0.47833613 0.15052327 0.44662373 0.43474672 0.90355587
#   0.37956481 0.81507912 0.13108238 0.24890979]
#  [0.2933705  0.56655688 0.82770487 0.32141662 0.26204165 0.59759696
#   0.48736437 0.7054866  0.99644329 0.95495365]
#  [0.69558304 0.92706007 0.10532988 0.44237098 0.0852581  0.45358325
#   0.79674373 0.01727729 0.13010803 0.07905847]
#  [0.64730885 0.74790675 0.98582573 0.78440304 0.98570155 0.84598173
#   0.17711475 0.14372273 0.19023984 0.41290578]
#  [0.89972379 0.23524983 0.78117543 0.806877   0.40495023 0.30895986
#   0.63104521 0.11532339 0.3009346  0.83154567]
#  [0.51638505 0.14521472 0.35682768 0.80764041 0.19008308 0.25194925
#   0.88125699 0.49423025 0.29600593 0.06152939]
#  [0.16179792 0.0152095  0.49652963 0.08602267 0.32199873 0.79014381
#   0.21604676 0.44878989 0.77516928 0.52487268]
#  [0.87558431 0.95388584 0.51796844 0.40192003 0.51048022 0.12305721
#   0.75776172 0.16582121 0.0573824  0.79763935]
#  [0.27010652 0.03209271 0.92163859 0.53448206 0.01682822 0.86764383
#   0.30191929 0.4573942  0.68658145 0.76486242]
#  [0.41217807 0.64173868 0.08628703 0.16619963 0.1575549  0.44720019
#   0.38249028 0.62771985 0.2170818  0.91941696]]
# 529.0296007985414

# %% [markdown]
# # III. Minimum residual scheme

# %% [markdown]
# ### Task III.1
#
# Implement the $\textit{minimum residual}$ scheme: an explicit non-stationary method, where at each step you select the iteration parameter $\tau_n$ to minimize the residual $\mathbf{r}_{n+1}$ given $\mathbf{r}_n$. Test it on a random matrix, study the convergence to the solution, in terms of the norm of the residual and the deviation from the ground truth solution (which you can obtain using a direct method). Study how the iteration parameter $\tau_n$ changes as iterations progress.
#
# (50% of the grade)

# %%
import numpy as np

def minres(A, b, n_iter=500, eps=1e-07):
    x = np.zeros_like(b)
    r = b - A @ x
    p = r.copy()
    T = []
    
    for i in range(n_iter):
        Ap = A @ p
        alpha = np.dot(r, r) / np.dot(p, Ap)
        x = x + alpha * p
        r = r - alpha * Ap
        beta = np.dot(r, r) / np.dot(p, Ap)
        p = r + beta * p
        T.append(alpha)
        
        if np.linalg.norm(r) < eps:
            break
    
    return x, T


x, T = minres(A, b)

print("Solución:")
print(x)
print("Paramentos de iteracion: ")
print(T)



#Pruebas para el vector solucion
rtol = 1e-5
atol = 1e-5


xx = np.linalg.solve(A, b)

np.testing.assert_allclose(A@x, b, rtol=rtol, atol=atol)
np.testing.assert_allclose(x, xx, rtol=rtol, atol=atol)
# Out:
# Solución:
# [-4.44822438e+67 -7.27627994e+67 -1.14617259e+68 -3.51617941e+67
#  -9.99307487e+67 -1.00919915e+68 -9.94818107e+66 -1.14072248e+68
#  -2.52497723e+67 -6.88116043e+67]
# Paramentos de iteracion:
# [0.24389601207037648, 4.0415054029090625, 0.01874689278658867, 0.9963402742733356, -0.43533746419048636, -1.1528962174617137, -0.04360830945492343, 0.21057521987413147, -2.4907451063370516, -0.03690811942878977, 0.9475562040730419, 0.7519101739222082, -0.30849434053152647, 0.2446878703349482, 1.9673912776639682, 0.40735604169072825, 2.1995134657433035, 0.013536649656789614, 1.8704239418153377, 0.10884213701845222, -0.07239393651030206, 0.22400533639587675, -1.4737753665903457, -0.13183041681164862, 0.27776757268998287, 2.6295228045794348, 0.0547669378950454, -0.2932203753083185, 0.29355523752133955, 2.797035638800494, 0.019479974659858987, 0.765118376633564, -0.5228696666161369, 0.3425310264894693, 1.1841533558748794, -0.17325594281028245, 0.33379153394813144, -3.7112960058204503, -0.002533461643434836, 0.2379909554016685, -1.3916428495837407, -0.13618685865681335, 0.2717061739688021, 7.1709127438980405, 0.0009307456456019581, 0.3205299305142053, -2.274109445017093, -0.016974830363874788, 0.21142445112440658, -0.9641140182336209, 0.5533244112797054, 0.49622867914755797, 1.0588477461100023, -0.6514330850737884, 0.31471157777518516, -0.9710436924131182, 233.99919655147085, 5.2532225069758455e-09, 0.2883673406717344, -1.4203236593998383, -0.062190006849904146, 0.21222029176736998, -1.6870491449927671, -0.3406534894702303, 3.5106492180419018, 0.009701427524047302, 0.5058395125367051, 533.9196618477557, 1.1943310515963007e-09, 0.26778373394899163, -1.9359784371374353, -0.02166182992385118, 0.221123599549875, -2.0598546780881213, -0.1862622426009514, 0.3426329429396473, 0.6217663901663346, -2.2061064227192393, -0.02429395768375868, 0.27911057186383487, 1.161233941896804, -8.725292704935727, -0.0003115566931284612, 0.3047643545827951, 2.2201949790144657, 0.14744441308519515, -0.08389683408899659, 0.20786321752616901, -1.512888090844706, -0.2187778744455167, 1.1846478127454374, 0.8067375824449421, -0.22867978850145457, 1.1834029718646373, -1.197581240282221, -0.04600057038066087, 1.3013986018889871, 6.193774246003892, 0.002903319746000923, 1.3672543907318253, 0.4072486390342741, 0.4205895429748094, -1.709395241176407, -0.06948257467207448, 0.31207879578098147, 1.5399472634647782, 1.1532766070568412, -0.05257455504084735, -0.033898699590775766, 0.2535343342191426, 2.571305199643171, 0.03508686004127858, 10.334614108096563, 0.00015054168234749317, 0.40244471705220086, -1.2404632799780613, -0.0748180404127625, 0.2224642711782665, -2.7195686190771196, -0.00966811547768936, 0.2504665160443961, -4.69545011112774, -0.003931583405274937, 0.28842606550954214, 2.8730263104438953, 0.09227572844408725, -0.19009298900847263, 0.22345032372572576, 1.0955621032123144, 1.2575672430958185, -0.46702692680439256, -0.027497482782305304, 0.2571652518182273, -2.524427997555543, -0.017436430102190825, 0.22981978275585757, 5.479714621818691, 0.012698458406267175, 1.0399470040613217, -0.23974324718472714, 0.7483250019024502, -0.9933141637704639, -0.1112760957843085, 0.2532594515694439, 0.7477072316280287, -2.0059827807577046, -0.015147332494109919, 0.2973367416658626, 6.89359758968593, 0.000955367444332917, 0.4017794223893125, -3.0673919550042257, -0.004828437237075785, 0.23179461613693697, -1.5541997214919507, -0.08393355744930969, 0.2410434148569545, 0.9656047352147733, -2.7059210477269904, -0.005493981278252497, 0.35413459586442975, 1.7715164916626156, -6.132119209191154, -2.072499072822286e-05, 0.28762352628056254, -3.345035155365175, -0.004502224872183527, 0.24609986543337475, -3.4881216909171275, -0.005615721347075566, 0.25723846113164156, -10.366849740118642, -0.0002171908530542803, 0.310395315273331, -30.65724369056445, -7.64024480866289e-06, 0.27902216669209823, -2.3224458374960943, -0.012899176193744344, 0.22447678237614105, -3.7165983304595183, -0.007109970108104314, 0.31274776192200326, 2.323784496809353, 0.07459457531185766, -0.19825035979592726, 0.2226598785115791, -2.2998173044700674, -0.01833882109004952, 0.21106523377619604, -0.981852563491104 ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-50-fe09fd251ce9> in <cell line: 40>()
#      38 xx = np.linalg.solve(A, b)
#      39
# ---> 40 np.testing.assert_allclose(A@x, b, rtol=rtol, atol=atol)
#      41 np.testing.assert_allclose(x, xx, rtol=rtol, atol=atol)
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/numpy/testing/_private/utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     842                                 verbose=verbose, header=header,
#     843                                 names=('x', 'y'), precision=precision)
# --> 844             raise AssertionError(msg)
#     845     except ValueError:
#     846         import traceback
#
# AssertionError:
# Not equal to tolerance rtol=1e-05, atol=1e-05
#
# Mismatched elements: 10 / 10 (100%)
# Max absolute difference: 4.59038464e+68
# Max relative difference: 2.92919795e+69
#  x: array([-3.475060e+68, -4.231370e+68, -1.989416e+68, -4.590385e+68,
#        -3.309453e+68, -2.241076e+68, -2.891921e+68, -3.280770e+68,
#        -3.531703e+68, -2.857975e+68])
#  y: array([0.697597, 0.771671, 0.441439, 0.507034, 0.191243, 0.595939,
#        0.098727, 0.496038, 0.764069, 0.971083])
